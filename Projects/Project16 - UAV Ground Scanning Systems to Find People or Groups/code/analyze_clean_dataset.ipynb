# %%
import glob
import os
from pandas import DataFrame

print("<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>")
pathToDataset = "./dataset"
listAlljpg = []
for filename in glob.glob(f"{pathToDataset}/*.jpg"):
    basename = os.path.basename(filename)
    numIndex = int(basename[:3])
    listAlljpg.append(numIndex)
listAlljpg.sort()

print(listAlljpg)
prev_i = None
count = 0
for i, v in enumerate(listAlljpg):
    if(i == 0):
        prev_v = v
    else:
        if((prev_v + 1) != v):
            print(f"Not continuous between {prev_v} and {v}")
            count +=1
        prev_v = v
print(f"Total not continuous: {count}")

#########################################
print("<<<<<<<<<<<<<<<<<annotation>>>>>>>>>>>>>>>>")
pathToAnnotation = "./annotation"
listAllAnno = []
for filename in glob.glob(f"{pathToAnnotation}/*.txt"):
    basename = os.path.basename(filename)
    numIndex = int(basename[:3])
    listAllAnno.append(numIndex)
listAllAnno.sort()

print(listAllAnno)
prev_i = None
count = 0
for i, v in enumerate(listAllAnno):
    if(i == 0):
        prev_v = v
    else:
        if((prev_v + 1) != v):
            print(f"Not continuous between {prev_v} and {v}")
            count +=1
        prev_v = v
print(f"Total not continuous: {count}")

#######not match
setImage = set(listAlljpg)
setAnno = set(listAllAnno)

setDiffImage = setImage - setAnno
setDiffAnno = setAnno - setImage

listDiffImage = list(setDiffImage)
listDiffAnno = list(setDiffAnno)

print(f"image cannot find a match at anno: {listDiffImage}")
print(f"anno cannot find a match at image: {listDiffAnno}")
# Out:
# <<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>
# [0, 1, 2, 3, 4, 5, 6, 8, 11, 13, 14, 15, 16, 18, 19, 21, 22, 23, 26, 28, 31, 35, 38, 40, 41, 42, 43, 44, 45, 47, 49, 51, 52, 53, 55, 56, 57, 58, 59, 60, 62, 63, 65, 68, 70, 71, 73, 74, 75, 77, 78, 79, 80, 81, 83, 86, 88, 89, 92, 95, 98, 99, 100, 101, 102, 103, 104, 106, 107, 109, 110, 111, 112, 113, 116, 117, 118, 119, 120, 121, 122, 123, 124, 126, 128, 130, 133, 134, 135, 136, 137, 138, 139, 140, 141, 145, 146, 147, 148, 149, 150, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 185, 186, 188, 190, 192, 193, 194, 195, 198, 199, 200, 202, 204, 206, 207, 208, 209, 213, 214, 215, 216, 217, 219, 220, 221, 222, 223, 225, 226, 228, 229, 230, 232, 233, 234, 235, 236, 237, 238, 239, 240, 243, 244, 246, 248, 250, 251, 252, 255, 257, 258, 259, 260, 261, 262, 263, 265, 266, 271, 272, 273, 275, 276, 277, 281, 283, 287, 288, 289, 290, 292, 294, 295, 296, 298, 299, 301, 302, 303, 304, 305, 306, 309, 310, 311, 312, 313, 314, 316, 318, 320, 321, 322, 323, 324, 325, 326, 329, 330, 331, 332, 334, 335, 338, 339, 341, 342, 344, 345, 346, 347, 348, 349, 351, 355, 356, 361, 363, 366, 367, 372, 373, 375, 376, 378, 380, 381, 382, 383, 385, 386, 388, 389, 390, 391, 393, 397, 398, 403, 406, 408, 409, 410, 411, 412, 413, 414, 416, 419, 420, 421, 423, 424, 425, 426, 427, 428, 429, 430, 431, 433, 434, 435, 437, 438, 439, 440, 442, 443, 444, 445, 446, 447, 451, 452, 454, 455, 457, 458, 460, 461, 462, 463, 464, 465, 467, 470, 472, 473, 474, 475, 476, 478, 479, 480, 484, 485, 488, 489, 491, 493, 494, 497, 498, 499, 500, 501, 502, 507, 508, 509, 510, 512, 513, 514, 515, 517, 518, 521, 524, 525, 526, 529, 530, 531, 532, 533, 535, 536, 537, 538, 540, 543, 544, 545, 549, 551, 554, 556, 558, 559, 560, 561, 563, 564, 565, 566, 567, 568, 569, 570, 572, 573, 574, 576, 579, 580, 582, 583, 584, 585, 586, 587, 588, 590, 591, 592, 593, 594, 596, 598]
# Not continuous between 6 and 8
# Not continuous between 8 and 11
# Not continuous between 11 and 13
# Not continuous between 16 and 18
# Not continuous between 19 and 21
# Not continuous between 23 and 26
# Not continuous between 26 and 28
# Not continuous between 28 and 31
# Not continuous between 31 and 35
# Not continuous between 35 and 38
# Not continuous between 38 and 40
# Not continuous between 45 and 47
# Not continuous between 47 and 49
# Not continuous between 49 and 51
# Not continuous between 53 and 55
# Not continuous between 60 and 62
# Not continuous between 63 and 65
# Not continuous between 65 and 68
# Not continuous between 68 and 70
# Not continuous between 71 and 73
# Not continuous between 75 and 77
# Not continuous between 81 and 83
# Not continuous between 83 and 86
# Not continuous between 86 and 88
# Not continuous between 89 and 92
# Not continuous between 92 and 95
# Not continuous between 95 and 98
# Not continuous between 104 and 106
# Not continuous between 107 and 109
# Not continuous between 113 and 116
# Not continuous between 124 and 126
# Not continuous between 126 and 128
# Not continuous between 128 and 130
# Not continuous between 130 and 133
# Not continuous between 141 and 145
# Not continuous between 150 and 153
# Not continuous between 167 and 170
# Not continuous between 182 and 185
# Not continuous between 186 and 188
# Not continuous between 188 and 190
# Not continuous between 190 and 192
# Not continuous between 195 and 198
# Not continuous between 200 and 202
# Not continuous between 202 and 204
# Not continuous between 204 and 206
# Not continuous between 209 and 213
# Not continuous between 217 and 219
# Not continuous between 223 and 225
# Not continuous between 226 and 228
# Not continuous between 230 and 232
# Not continuous between 240 and 243
# Not continuous between 244 and 246
# Not continuous between 246 and 248
# Not continuous between 248 and 250
# Not continuous between 252 and 255
# Not continuous between 255 and 257
# Not continuous between 263 and 265
# Not continuous between 266 and 271
# Not continuous between 273 and 275
# Not continuous between 277 and 281
# Not continuous between 281 and 283
# Not continuous between 283 and 287
# Not continuous between 290 and 292
# Not continuous between 292 and 294
# Not continuous between 296 and 298
# Not continuous between 299 and 301
# Not continuous between 306 and 309
# Not continuous between 314 and 316
# Not continuous between 316 and 318
# Not continuous between 318 and 320
# Not continuous between 326 and 329
# Not continuous between 332 and 334
# Not continuous between 335 and 338
# Not continuous between 339 and 341
# Not continuous between 342 and 344
# Not continuous between 349 and 351
# Not continuous between 351 and 355
# Not continuous between 356 and 361
# Not continuous between 361 and 363
# Not continuous between 363 and 366
# Not continuous between 367 and 372
# Not continuous between 373 and 375
# Not continuous between 376 and 378
# Not continuous between 378 and 380
# Not continuous between 383 and 385
# Not continuous between 386 and 388
# Not continuous between 391 and 393
# Not continuous between 393 and 397
# Not continuous between 398 and 403
# Not continuous between 403 and 406
# Not continuous between 406 and 408
# Not continuous between 414 and 416
# Not continuous between 416 and 419
# Not continuous between 421 and 423
# Not continuous between 431 and 433
# Not continuous between 435 and 437
# Not continuous between 440 and 442
# Not continuous between 447 and 451
# Not continuous between 452 and 454
# Not continuous between 455 and 457
# Not continuous between 458 and 460
# Not continuous between 465 and 467
# Not continuous between 467 and 470
# Not continuous between 470 and 472
# Not continuous between 476 and 478
# Not continuous between 480 and 484
# Not continuous between 485 and 488
# Not continuous between 489 and 491
# Not continuous between 491 and 493
# Not continuous between 494 and 497
# Not continuous between 502 and 507
# Not continuous between 510 and 512
# Not continuous between 515 and 517
# Not continuous between 518 and 521
# Not continuous between 521 and 524
# Not continuous between 526 and 529
# Not continuous between 533 and 535
# Not continuous between 538 and 540
# Not continuous between 540 and 543
# Not continuous between 545 and 549
# Not continuous between 549 and 551
# Not continuous between 551 and 554
# Not continuous between 554 and 556
# Not continuous between 556 and 558
# Not continuous between 561 and 563
# Not continuous between 570 and 572
# Not continuous between 574 and 576
# Not continuous between 576 and 579
# Not continuous between 580 and 582
# Not continuous between 588 and 590
# Not continuous between 594 and 596
# Not continuous between 596 and 598
# Total not continuous: 132
# <<<<<<<<<<<<<<<<<annotation>>>>>>>>>>>>>>>>
# [0, 1, 2, 3, 4, 5, 6, 14, 15, 18, 19, 21, 22, 26, 28, 31, 35, 38, 40, 42, 43, 44, 45, 47, 49, 51, 52, 55, 57, 59, 60, 62, 63, 65, 68, 70, 71, 73, 74, 77, 78, 79, 80, 86, 88, 92, 95, 98, 99, 100, 102, 103, 104, 106, 107, 109, 110, 112, 113, 116, 117, 118, 119, 120, 121, 122, 123, 124, 126, 128, 130, 133, 135, 136, 138, 139, 140, 141, 145, 146, 147, 148, 149, 150, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 171, 172, 173, 175, 176, 177, 179, 180, 181, 185, 186, 188, 190, 192, 193, 194, 198, 199, 200, 202, 204, 206, 207, 209, 213, 214, 215, 216, 217, 219, 220, 221, 222, 223, 225, 226, 228, 229, 230, 232, 233, 235, 236, 237, 238, 239, 240, 243, 246, 248, 250, 251, 255, 257, 258, 259, 260, 261, 262, 263, 265, 266, 271, 272, 273, 275, 276, 277, 281, 283, 287, 288, 289, 290, 292, 294, 295, 296, 298, 299, 301, 302, 303, 304, 305, 306, 309, 310, 311, 313, 316, 318, 320, 321, 322, 323, 324, 325, 326, 329, 330, 331, 332, 334, 335, 338, 339, 341, 342, 344, 345, 346, 348, 349, 351, 355, 356, 361, 363, 366, 367, 372, 373, 375, 376, 378, 382, 383, 386, 389, 390, 391, 397, 403, 406, 408, 409, 411, 412, 413, 414, 416, 421, 423, 424, 425, 426, 427, 428, 429, 430, 433, 434, 435, 437, 438, 439, 440, 442, 443, 444, 447, 451, 452, 454, 455, 457, 458, 460, 461, 462, 463, 464, 465, 467, 470, 472, 473, 474, 475, 476, 478, 479, 480, 485, 488, 489, 491, 493, 494, 497, 498, 500, 501, 502, 507, 509, 510, 512, 513, 514, 515, 517, 518, 521, 524, 525, 526, 529, 531, 532, 535, 536, 537, 538, 540, 543, 544, 545, 549, 551, 554, 556, 558, 559, 564, 565, 566, 567, 568, 570, 572, 573, 574, 576, 582, 583, 584, 585, 586, 587, 588, 591, 592, 593, 594, 596, 598]
# Not continuous between 6 and 14
# Not continuous between 15 and 18
# Not continuous between 19 and 21
# Not continuous between 22 and 26
# Not continuous between 26 and 28
# Not continuous between 28 and 31
# Not continuous between 31 and 35
# Not continuous between 35 and 38
# Not continuous between 38 and 40
# Not continuous between 40 and 42
# Not continuous between 45 and 47
# Not continuous between 47 and 49
# Not continuous between 49 and 51
# Not continuous between 52 and 55
# Not continuous between 55 and 57
# Not continuous between 57 and 59
# Not continuous between 60 and 62
# Not continuous between 63 and 65
# Not continuous between 65 and 68
# Not continuous between 68 and 70
# Not continuous between 71 and 73
# Not continuous between 74 and 77
# Not continuous between 80 and 86
# Not continuous between 86 and 88
# Not continuous between 88 and 92
# Not continuous between 92 and 95
# Not continuous between 95 and 98
# Not continuous between 100 and 102
# Not continuous between 104 and 106
# Not continuous between 107 and 109
# Not continuous between 110 and 112
# Not continuous between 113 and 116
# Not continuous between 124 and 126
# Not continuous between 126 and 128
# Not continuous between 128 and 130
# Not continuous between 130 and 133
# Not continuous between 133 and 135
# Not continuous between 136 and 138
# Not continuous between 141 and 145
# Not continuous between 150 and 153
# Not continuous between 167 and 171
# Not continuous between 173 and 175
# Not continuous between 177 and 179
# Not continuous between 181 and 185
# Not continuous between 186 and 188
# Not continuous between 188 and 190
# Not continuous between 190 and 192
# Not continuous between 194 and 198
# Not continuous between 200 and 202
# Not continuous between 202 and 204
# Not continuous between 204 and 206
# Not continuous between 207 and 209
# Not continuous between 209 and 213
# Not continuous between 217 and 219
# Not continuous between 223 and 225
# Not continuous between 226 and 228
# Not continuous between 230 and 232
# Not continuous between 233 and 235
# Not continuous between 240 and 243
# Not continuous between 243 and 246
# Not continuous between 246 and 248
# Not continuous between 248 and 250
# Not continuous between 251 and 255
# Not continuous between 255 and 257
# Not continuous between 263 and 265
# Not continuous between 266 and 271
# Not continuous between 273 and 275
# Not continuous between 277 and 281
# Not continuous between 281 and 283
# Not continuous between 283 and 287
# Not continuous between 290 and 292
# Not continuous between 292 and 294
# Not continuous between 296 and 298
# Not continuous between 299 and 301
# Not continuous between 306 and 309
# Not continuous between 311 and 313
# Not continuous between 313 and 316
# Not continuous between 316 and 318
# Not continuous between 318 and 320
# Not continuous between 326 and 329
# Not continuous between 332 and 334
# Not continuous between 335 and 338
# Not continuous between 339 and 341
# Not continuous between 342 and 344
# Not continuous between 346 and 348
# Not continuous between 349 and 351
# Not continuous between 351 and 355
# Not continuous between 356 and 361
# Not continuous between 361 and 363
# Not continuous between 363 and 366
# Not continuous between 367 and 372
# Not continuous between 373 and 375
# Not continuous between 376 and 378
# Not continuous between 378 and 382
# Not continuous between 383 and 386
# Not continuous between 386 and 389
# Not continuous between 391 and 397
# Not continuous between 397 and 403
# Not continuous between 403 and 406
# Not continuous between 406 and 408
# Not continuous between 409 and 411
# Not continuous between 414 and 416
# Not continuous between 416 and 421
# Not continuous between 421 and 423
# Not continuous between 430 and 433
# Not continuous between 435 and 437
# Not continuous between 440 and 442
# Not continuous between 444 and 447
# Not continuous between 447 and 451
# Not continuous between 452 and 454
# Not continuous between 455 and 457
# Not continuous between 458 and 460
# Not continuous between 465 and 467
# Not continuous between 467 and 470
# Not continuous between 470 and 472
# Not continuous between 476 and 478
# Not continuous between 480 and 485
# Not continuous between 485 and 488
# Not continuous between 489 and 491
# Not continuous between 491 and 493
# Not continuous between 494 and 497
# Not continuous between 498 and 500
# Not continuous between 502 and 507
# Not continuous between 507 and 509
# Not continuous between 510 and 512
# Not continuous between 515 and 517
# Not continuous between 518 and 521
# Not continuous between 521 and 524
# Not continuous between 526 and 529
# Not continuous between 529 and 531
# Not continuous between 532 and 535
# Not continuous between 538 and 540
# Not continuous between 540 and 543
# Not continuous between 545 and 549
# Not continuous between 549 and 551
# Not continuous between 551 and 554
# Not continuous between 554 and 556
# Not continuous between 556 and 558
# Not continuous between 559 and 564
# Not continuous between 568 and 570
# Not continuous between 570 and 572
# Not continuous between 574 and 576
# Not continuous between 576 and 582
# Not continuous between 588 and 591
# Not continuous between 594 and 596
# Not continuous between 596 and 598
# Total not continuous: 146
# image cannot find a match at anno: [385, 388, 134, 8, 137, 393, 11, 13, 398, 16, 530, 533, 23, 410, 419, 420, 41, 170, 174, 431, 560, 561, 178, 563, 53, 182, 56, 312, 58, 314, 569, 445, 446, 195, 579, 580, 75, 590, 208, 81, 83, 89, 347, 484, 101, 234, 508, 111, 499, 244, 380, 252, 381]
# anno cannot find a match at image: []

# %%
import glob
import os
from pandas import DataFrame

# %%
import glob
import os
from pandas import DataFrame

print("<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>")
pathToDataset = "./train_image_folder"
listAlljpg = []
for filename in glob.glob(f"{pathToDataset}/*.jpg"):
    basename = os.path.basename(filename)
    numIndex = int(basename[:3])
    listAlljpg.append(numIndex)
listAlljpg.sort()

print(listAlljpg)
prev_i = None
count = 0
for i, v in enumerate(listAlljpg):
    if(i == 0):
        prev_v = v
    else:
        if((prev_v + 1) != v):
            print(f"Not continuous between {prev_v} and {v}")
            count +=1
        prev_v = v
print(f"Total not continuous: {count}")

#########################################
print("<<<<<<<<<<<<<<<<<annotation>>>>>>>>>>>>>>>>")
pathToAnnotation = "./train_annot_folder"
listAllAnno = []
for filename in glob.glob(f"{pathToAnnotation}/*.txt"):
    basename = os.path.basename(filename)
    numIndex = int(basename[:3])
    listAllAnno.append(numIndex)
listAllAnno.sort()

print(listAllAnno)
prev_i = None
count = 0
for i, v in enumerate(listAllAnno):
    if(i == 0):
        prev_v = v
    else:
        if((prev_v + 1) != v):
            print(f"Not continuous between {prev_v} and {v}")
            count +=1
        prev_v = v
print(f"Total not continuous: {count}")

#######not match
setImage = set(listAlljpg)
setAnno = set(listAllAnno)

setDiffImage = setImage - setAnno
setDiffAnno = setAnno - setImage

listDiffImage = list(setDiffImage)
listDiffAnno = list(setDiffAnno)

print(f"image cannot find a match at anno: {listDiffImage}")
print(f"anno cannot find a match at image: {listDiffAnno}")
# Out:
# <<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>
# [0, 1, 2, 3, 4, 5, 6, 8, 11, 13, 14, 15, 16, 18, 19, 21, 22, 23, 26, 28, 31, 35, 38, 40, 41, 42, 43, 44, 45, 47, 49, 51, 52, 53, 55, 56, 57, 58, 59, 60, 62, 63, 65, 68, 70, 71, 73, 74, 75, 77, 78, 79, 80, 81, 83, 86, 88, 89, 92, 95, 98, 99, 100, 101, 102, 103, 104, 106, 107, 109, 110, 111, 112, 113, 116, 117, 118, 119, 120, 121, 122, 123, 124, 126, 128, 130, 133, 134, 135, 136, 137, 138, 139, 140, 141, 145, 146, 147, 148, 149, 150, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 185, 186, 188, 190, 192, 193, 194, 195, 198, 199, 200, 202, 204, 206, 207, 208, 209, 213, 214, 215, 216, 217, 219, 220, 221, 222, 223, 225, 226, 228, 229, 230, 232, 233, 234, 235, 236, 237, 238, 239, 240, 243, 244, 246, 248, 250, 251, 252, 255, 257, 258, 259, 260, 261, 262, 263, 265, 266, 271, 272, 273, 275, 276, 277, 281, 283, 287, 288, 289, 290, 292, 294, 295, 296, 298, 299, 301, 302, 303, 304, 305, 306, 309, 310, 311, 312, 313, 314, 316, 318, 320, 321, 322, 323, 324, 325, 326, 329, 330, 331, 332, 334, 335, 338, 339, 341, 342, 344, 345, 346, 347, 348, 349, 351, 355, 356, 361, 363, 366, 367, 372, 373, 375, 376, 378, 380, 381, 382, 383, 385, 386, 388, 389, 390, 391, 393, 397, 398, 403, 406, 408, 409, 410, 411, 412, 413, 414, 416, 419, 420, 421, 423, 424, 425, 426, 427, 428, 429, 430, 431, 433, 434, 435, 437, 438, 439, 440, 442, 443, 444, 445, 446, 447, 451, 452, 454, 455, 457, 458, 460, 461, 462, 463, 464, 465, 467, 470, 472, 473, 474, 475, 476, 478, 479, 480, 484, 485, 488, 489, 491, 493, 494, 497, 498, 499, 500, 501, 502, 507, 508, 509, 510, 512, 513, 514, 515, 517, 518, 521, 524, 525, 526, 529, 530, 531, 532, 533, 535, 536, 537, 538, 540, 543, 544, 545, 549, 551, 554, 556, 558, 559, 560, 561, 563, 564, 565, 566, 567, 568, 569, 570, 572, 573, 574, 576, 579, 580, 582, 583, 584, 585, 586, 587, 588, 590, 591, 592, 593, 594, 596, 598]
# Not continuous between 6 and 8
# Not continuous between 8 and 11
# Not continuous between 11 and 13
# Not continuous between 16 and 18
# Not continuous between 19 and 21
# Not continuous between 23 and 26
# Not continuous between 26 and 28
# Not continuous between 28 and 31
# Not continuous between 31 and 35
# Not continuous between 35 and 38
# Not continuous between 38 and 40
# Not continuous between 45 and 47
# Not continuous between 47 and 49
# Not continuous between 49 and 51
# Not continuous between 53 and 55
# Not continuous between 60 and 62
# Not continuous between 63 and 65
# Not continuous between 65 and 68
# Not continuous between 68 and 70
# Not continuous between 71 and 73
# Not continuous between 75 and 77
# Not continuous between 81 and 83
# Not continuous between 83 and 86
# Not continuous between 86 and 88
# Not continuous between 89 and 92
# Not continuous between 92 and 95
# Not continuous between 95 and 98
# Not continuous between 104 and 106
# Not continuous between 107 and 109
# Not continuous between 113 and 116
# Not continuous between 124 and 126
# Not continuous between 126 and 128
# Not continuous between 128 and 130
# Not continuous between 130 and 133
# Not continuous between 141 and 145
# Not continuous between 150 and 153
# Not continuous between 167 and 170
# Not continuous between 182 and 185
# Not continuous between 186 and 188
# Not continuous between 188 and 190
# Not continuous between 190 and 192
# Not continuous between 195 and 198
# Not continuous between 200 and 202
# Not continuous between 202 and 204
# Not continuous between 204 and 206
# Not continuous between 209 and 213
# Not continuous between 217 and 219
# Not continuous between 223 and 225
# Not continuous between 226 and 228
# Not continuous between 230 and 232
# Not continuous between 240 and 243
# Not continuous between 244 and 246
# Not continuous between 246 and 248
# Not continuous between 248 and 250
# Not continuous between 252 and 255
# Not continuous between 255 and 257
# Not continuous between 263 and 265
# Not continuous between 266 and 271
# Not continuous between 273 and 275
# Not continuous between 277 and 281
# Not continuous between 281 and 283
# Not continuous between 283 and 287
# Not continuous between 290 and 292
# Not continuous between 292 and 294
# Not continuous between 296 and 298
# Not continuous between 299 and 301
# Not continuous between 306 and 309
# Not continuous between 314 and 316
# Not continuous between 316 and 318
# Not continuous between 318 and 320
# Not continuous between 326 and 329
# Not continuous between 332 and 334
# Not continuous between 335 and 338
# Not continuous between 339 and 341
# Not continuous between 342 and 344
# Not continuous between 349 and 351
# Not continuous between 351 and 355
# Not continuous between 356 and 361
# Not continuous between 361 and 363
# Not continuous between 363 and 366
# Not continuous between 367 and 372
# Not continuous between 373 and 375
# Not continuous between 376 and 378
# Not continuous between 378 and 380
# Not continuous between 383 and 385
# Not continuous between 386 and 388
# Not continuous between 391 and 393
# Not continuous between 393 and 397
# Not continuous between 398 and 403
# Not continuous between 403 and 406
# Not continuous between 406 and 408
# Not continuous between 414 and 416
# Not continuous between 416 and 419
# Not continuous between 421 and 423
# Not continuous between 431 and 433
# Not continuous between 435 and 437
# Not continuous between 440 and 442
# Not continuous between 447 and 451
# Not continuous between 452 and 454
# Not continuous between 455 and 457
# Not continuous between 458 and 460
# Not continuous between 465 and 467
# Not continuous between 467 and 470
# Not continuous between 470 and 472
# Not continuous between 476 and 478
# Not continuous between 480 and 484
# Not continuous between 485 and 488
# Not continuous between 489 and 491
# Not continuous between 491 and 493
# Not continuous between 494 and 497
# Not continuous between 502 and 507
# Not continuous between 510 and 512
# Not continuous between 515 and 517
# Not continuous between 518 and 521
# Not continuous between 521 and 524
# Not continuous between 526 and 529
# Not continuous between 533 and 535
# Not continuous between 538 and 540
# Not continuous between 540 and 543
# Not continuous between 545 and 549
# Not continuous between 549 and 551
# Not continuous between 551 and 554
# Not continuous between 554 and 556
# Not continuous between 556 and 558
# Not continuous between 561 and 563
# Not continuous between 570 and 572
# Not continuous between 574 and 576
# Not continuous between 576 and 579
# Not continuous between 580 and 582
# Not continuous between 588 and 590
# Not continuous between 594 and 596
# Not continuous between 596 and 598
# Total not continuous: 132
# <<<<<<<<<<<<<<<<<annotation>>>>>>>>>>>>>>>>
# [0, 1, 2, 3, 4, 5, 6, 14, 15, 18, 19, 21, 22, 26, 28, 31, 35, 38, 40, 42, 43, 44, 45, 47, 49, 51, 52, 55, 57, 59, 60, 62, 63, 65, 68, 70, 71, 73, 74, 77, 78, 79, 80, 86, 88, 92, 95, 98, 99, 100, 102, 103, 104, 106, 107, 109, 110, 112, 113, 116, 117, 118, 119, 120, 121, 122, 123, 124, 126, 128, 130, 133, 135, 136, 138, 139, 140, 141, 145, 146, 147, 148, 149, 150, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 171, 172, 173, 175, 176, 177, 179, 180, 181, 185, 186, 188, 190, 192, 193, 194, 198, 199, 200, 202, 204, 206, 207, 209, 213, 214, 215, 216, 217, 219, 220, 221, 222, 223, 225, 226, 228, 229, 230, 232, 233, 235, 236, 237, 238, 239, 240, 243, 246, 248, 250, 251, 255, 257, 258, 259, 260, 261, 262, 263, 265, 266, 271, 272, 273, 275, 276, 277, 281, 283, 287, 288, 289, 290, 292, 294, 295, 296, 298, 299, 301, 302, 303, 304, 305, 306, 309, 310, 311, 313, 316, 318, 320, 321, 322, 323, 324, 325, 326, 329, 330, 331, 332, 334, 335, 338, 339, 341, 342, 344, 345, 346, 348, 349, 351, 355, 356, 361, 363, 366, 367, 372, 373, 375, 376, 378, 382, 383, 386, 389, 390, 391, 397, 403, 406, 408, 409, 411, 412, 413, 414, 416, 421, 423, 424, 425, 426, 427, 428, 429, 430, 433, 434, 435, 437, 438, 439, 440, 442, 443, 444, 447, 451, 452, 454, 455, 457, 458, 460, 461, 462, 463, 464, 465, 467, 470, 472, 473, 474, 475, 476, 478, 479, 480, 485, 488, 489, 491, 493, 494, 497, 498, 500, 501, 502, 507, 509, 510, 512, 513, 514, 515, 517, 518, 521, 524, 525, 526, 529, 531, 532, 535, 536, 537, 538, 540, 543, 544, 545, 549, 551, 554, 556, 558, 559, 564, 565, 566, 567, 568, 570, 572, 573, 574, 576, 582, 583, 584, 585, 586, 587, 588, 591, 592, 593, 594, 596, 598]
# Not continuous between 6 and 14
# Not continuous between 15 and 18
# Not continuous between 19 and 21
# Not continuous between 22 and 26
# Not continuous between 26 and 28
# Not continuous between 28 and 31
# Not continuous between 31 and 35
# Not continuous between 35 and 38
# Not continuous between 38 and 40
# Not continuous between 40 and 42
# Not continuous between 45 and 47
# Not continuous between 47 and 49
# Not continuous between 49 and 51
# Not continuous between 52 and 55
# Not continuous between 55 and 57
# Not continuous between 57 and 59
# Not continuous between 60 and 62
# Not continuous between 63 and 65
# Not continuous between 65 and 68
# Not continuous between 68 and 70
# Not continuous between 71 and 73
# Not continuous between 74 and 77
# Not continuous between 80 and 86
# Not continuous between 86 and 88
# Not continuous between 88 and 92
# Not continuous between 92 and 95
# Not continuous between 95 and 98
# Not continuous between 100 and 102
# Not continuous between 104 and 106
# Not continuous between 107 and 109
# Not continuous between 110 and 112
# Not continuous between 113 and 116
# Not continuous between 124 and 126
# Not continuous between 126 and 128
# Not continuous between 128 and 130
# Not continuous between 130 and 133
# Not continuous between 133 and 135
# Not continuous between 136 and 138
# Not continuous between 141 and 145
# Not continuous between 150 and 153
# Not continuous between 167 and 171
# Not continuous between 173 and 175
# Not continuous between 177 and 179
# Not continuous between 181 and 185
# Not continuous between 186 and 188
# Not continuous between 188 and 190
# Not continuous between 190 and 192
# Not continuous between 194 and 198
# Not continuous between 200 and 202
# Not continuous between 202 and 204
# Not continuous between 204 and 206
# Not continuous between 207 and 209
# Not continuous between 209 and 213
# Not continuous between 217 and 219
# Not continuous between 223 and 225
# Not continuous between 226 and 228
# Not continuous between 230 and 232
# Not continuous between 233 and 235
# Not continuous between 240 and 243
# Not continuous between 243 and 246
# Not continuous between 246 and 248
# Not continuous between 248 and 250
# Not continuous between 251 and 255
# Not continuous between 255 and 257
# Not continuous between 263 and 265
# Not continuous between 266 and 271
# Not continuous between 273 and 275
# Not continuous between 277 and 281
# Not continuous between 281 and 283
# Not continuous between 283 and 287
# Not continuous between 290 and 292
# Not continuous between 292 and 294
# Not continuous between 296 and 298
# Not continuous between 299 and 301
# Not continuous between 306 and 309
# Not continuous between 311 and 313
# Not continuous between 313 and 316
# Not continuous between 316 and 318
# Not continuous between 318 and 320
# Not continuous between 326 and 329
# Not continuous between 332 and 334
# Not continuous between 335 and 338
# Not continuous between 339 and 341
# Not continuous between 342 and 344
# Not continuous between 346 and 348
# Not continuous between 349 and 351
# Not continuous between 351 and 355
# Not continuous between 356 and 361
# Not continuous between 361 and 363
# Not continuous between 363 and 366
# Not continuous between 367 and 372
# Not continuous between 373 and 375
# Not continuous between 376 and 378
# Not continuous between 378 and 382
# Not continuous between 383 and 386
# Not continuous between 386 and 389
# Not continuous between 391 and 397
# Not continuous between 397 and 403
# Not continuous between 403 and 406
# Not continuous between 406 and 408
# Not continuous between 409 and 411
# Not continuous between 414 and 416
# Not continuous between 416 and 421
# Not continuous between 421 and 423
# Not continuous between 430 and 433
# Not continuous between 435 and 437
# Not continuous between 440 and 442
# Not continuous between 444 and 447
# Not continuous between 447 and 451
# Not continuous between 452 and 454
# Not continuous between 455 and 457
# Not continuous between 458 and 460
# Not continuous between 465 and 467
# Not continuous between 467 and 470
# Not continuous between 470 and 472
# Not continuous between 476 and 478
# Not continuous between 480 and 485
# Not continuous between 485 and 488
# Not continuous between 489 and 491
# Not continuous between 491 and 493
# Not continuous between 494 and 497
# Not continuous between 498 and 500
# Not continuous between 502 and 507
# Not continuous between 507 and 509
# Not continuous between 510 and 512
# Not continuous between 515 and 517
# Not continuous between 518 and 521
# Not continuous between 521 and 524
# Not continuous between 526 and 529
# Not continuous between 529 and 531
# Not continuous between 532 and 535
# Not continuous between 538 and 540
# Not continuous between 540 and 543
# Not continuous between 545 and 549
# Not continuous between 549 and 551
# Not continuous between 551 and 554
# Not continuous between 554 and 556
# Not continuous between 556 and 558
# Not continuous between 559 and 564
# Not continuous between 568 and 570
# Not continuous between 570 and 572
# Not continuous between 574 and 576
# Not continuous between 576 and 582
# Not continuous between 588 and 591
# Not continuous between 594 and 596
# Not continuous between 596 and 598
# Total not continuous: 146
# image cannot find a match at anno: [385, 388, 134, 8, 137, 393, 11, 13, 398, 16, 530, 533, 23, 410, 419, 420, 41, 170, 174, 431, 560, 561, 178, 563, 53, 182, 56, 312, 58, 314, 569, 445, 446, 195, 579, 580, 75, 590, 208, 81, 83, 89, 347, 484, 101, 234, 508, 111, 499, 244, 380, 252, 381]
# anno cannot find a match at image: []

# %%
df = DataFrame(listDiffImage,columns=['notExistAnno'])
df
# Out:
#     notExistAnno
# 0            385
# 1            388
# 2            134
# 3              8
# 4            137
# 5            393
# 6             11
# 7             13
# 8            398
# 9             16
# 10           530
# 11           533
# 12            23
# 13           410
# 14           419
# 15           420
# 16            41
# 17           170
# 18           174
# 19           431
# 20           560
# 21           561
# 22           178
# 23           563
# 24            53
# 25           182
# 26            56
# 27           312
# 28            58
# 29           314
# 30           569
# 31           445
# 32           446
# 33           195
# 34           579
# 35           580
# 36            75
# 37           590
# 38           208
# 39            81
# 40            83
# 41            89
# 42           347
# 43           484
# 44           101
# 45           234
# 46           508
# 47           111
# 48           499
# 49           244
# 50           380
# 51           252
# 52           381

# %%
with open("notExistAnno.csv",'w') as f:
    df.to_csv('notExistAnno.csv', index=False)

# %%
import pandas as pd

pathToAnnotation = "./train_annot_folder"
df = pd.read_csv('notExistAnno.csv')

df.head()
# Out:
#    notExistAnno
# 0           385
# 1           388
# 2           134
# 3             8
# 4           137

# %%
for v in df['notExistAnno']:
    path = f"{pathToAnnotation}/{v:0>3}.txt"
    print(path)
#     os.remove(path)
    with open(path, 'w'):
        pass
# Out:
# ./train_annot_folder/385.txt
# ./train_annot_folder/388.txt
# ./train_annot_folder/134.txt
# ./train_annot_folder/008.txt
# ./train_annot_folder/137.txt
# ./train_annot_folder/393.txt
# ./train_annot_folder/011.txt
# ./train_annot_folder/013.txt
# ./train_annot_folder/398.txt
# ./train_annot_folder/016.txt
# ./train_annot_folder/530.txt
# ./train_annot_folder/533.txt
# ./train_annot_folder/023.txt
# ./train_annot_folder/410.txt
# ./train_annot_folder/419.txt
# ./train_annot_folder/420.txt
# ./train_annot_folder/041.txt
# ./train_annot_folder/170.txt
# ./train_annot_folder/174.txt
# ./train_annot_folder/431.txt
# ./train_annot_folder/560.txt
# ./train_annot_folder/561.txt
# ./train_annot_folder/178.txt
# ./train_annot_folder/563.txt
# ./train_annot_folder/053.txt
# ./train_annot_folder/182.txt
# ./train_annot_folder/056.txt
# ./train_annot_folder/312.txt
# ./train_annot_folder/058.txt
# ./train_annot_folder/314.txt
# ./train_annot_folder/569.txt
# ./train_annot_folder/445.txt
# ./train_annot_folder/446.txt
# ./train_annot_folder/195.txt
# ./train_annot_folder/579.txt
# ./train_annot_folder/580.txt
# ./train_annot_folder/075.txt
# ./train_annot_folder/590.txt
# ./train_annot_folder/208.txt
# ./train_annot_folder/081.txt
# ./train_annot_folder/083.txt
# ./train_annot_folder/089.txt
# ./train_annot_folder/347.txt
# ./train_annot_folder/484.txt
# ./train_annot_folder/101.txt
# ./train_annot_folder/234.txt
# ./train_annot_folder/508.txt
# ./train_annot_folder/111.txt
# ./train_annot_folder/499.txt
# ./train_annot_folder/244.txt
# ./train_annot_folder/380.txt
# ./train_annot_folder/252.txt
# ./train_annot_folder/381.txt

# %%
import glob
import os
from pandas import DataFrame

print("<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>")
pathToDataset = "./train_image_folder"
listAlljpg = []
for filename in glob.glob(f"{pathToDataset}/*.jpg"):
    basename = os.path.basename(filename)
    numIndex = int(basename[:3])
    listAlljpg.append(numIndex)
listAlljpg.sort()

print(listAlljpg)
prev_i = None
count = 0
for i, v in enumerate(listAlljpg):
    if(i == 0):
        prev_v = v
    else:
        if((prev_v + 1) != v):
            print(f"Not continuous between {prev_v} and {v}")
            count +=1
        prev_v = v
print(f"Total not continuous: {count}")

#########################################
print("<<<<<<<<<<<<<<<<<annotation>>>>>>>>>>>>>>>>")
pathToAnnotation = "./train_annot_folder"
listAllAnno = []
for filename in glob.glob(f"{pathToAnnotation}/*.txt"):
    basename = os.path.basename(filename)
    numIndex = int(basename[:3])
    listAllAnno.append(numIndex)
listAllAnno.sort()

print(listAllAnno)
prev_i = None
count = 0
for i, v in enumerate(listAllAnno):
    if(i == 0):
        prev_v = v
    else:
        if((prev_v + 1) != v):
            print(f"Not continuous between {prev_v} and {v}")
            count +=1
        prev_v = v
print(f"Total not continuous: {count}")

#######not match
setImage = set(listAlljpg)
setAnno = set(listAllAnno)

setDiffImage = setImage - setAnno
setDiffAnno = setAnno - setImage

listDiffImage = list(setDiffImage)
listDiffAnno = list(setDiffAnno)

print(f"image cannot find a match at anno: {listDiffImage}")
print(f"anno cannot find a match at image: {listDiffAnno}")
# Out:
# <<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>
# [0, 1, 2, 3, 4, 5, 6, 8, 11, 13, 14, 15, 16, 18, 19, 21, 22, 23, 26, 28, 31, 35, 38, 40, 41, 42, 43, 44, 45, 47, 49, 51, 52, 53, 55, 56, 57, 58, 59, 60, 62, 63, 65, 68, 70, 71, 73, 74, 75, 77, 78, 79, 80, 81, 83, 86, 88, 89, 92, 95, 98, 99, 100, 101, 102, 103, 104, 106, 107, 109, 110, 111, 112, 113, 116, 117, 118, 119, 120, 121, 122, 123, 124, 126, 128, 130, 133, 134, 135, 136, 137, 138, 139, 140, 141, 145, 146, 147, 148, 149, 150, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 185, 186, 188, 190, 192, 193, 194, 195, 198, 199, 200, 202, 204, 206, 207, 208, 209, 213, 214, 215, 216, 217, 219, 220, 221, 222, 223, 225, 226, 228, 229, 230, 232, 233, 234, 235, 236, 237, 238, 239, 240, 243, 244, 246, 248, 250, 251, 252, 255, 257, 258, 259, 260, 261, 262, 263, 265, 266, 271, 272, 273, 275, 276, 277, 281, 283, 287, 288, 289, 290, 292, 294, 295, 296, 298, 299, 301, 302, 303, 304, 305, 306, 309, 310, 311, 312, 313, 314, 316, 318, 320, 321, 322, 323, 324, 325, 326, 329, 330, 331, 332, 334, 335, 338, 339, 341, 342, 344, 345, 346, 347, 348, 349, 351, 355, 356, 361, 363, 366, 367, 372, 373, 375, 376, 378, 380, 381, 382, 383, 385, 386, 388, 389, 390, 391, 393, 397, 398, 403, 406, 408, 409, 410, 411, 412, 413, 414, 416, 419, 420, 421, 423, 424, 425, 426, 427, 428, 429, 430, 431, 433, 434, 435, 437, 438, 439, 440, 442, 443, 444, 445, 446, 447, 451, 452, 454, 455, 457, 458, 460, 461, 462, 463, 464, 465, 467, 470, 472, 473, 474, 475, 476, 478, 479, 480, 484, 485, 488, 489, 491, 493, 494, 497, 498, 499, 500, 501, 502, 507, 508, 509, 510, 512, 513, 514, 515, 517, 518, 521, 524, 525, 526, 529, 530, 531, 532, 533, 535, 536, 537, 538, 540, 543, 544, 545, 549, 551, 554, 556, 558, 559, 560, 561, 563, 564, 565, 566, 567, 568, 569, 570, 572, 573, 574, 576, 579, 580, 582, 583, 584, 585, 586, 587, 588, 590, 591, 592, 593, 594, 596, 598]
# Not continuous between 6 and 8
# Not continuous between 8 and 11
# Not continuous between 11 and 13
# Not continuous between 16 and 18
# Not continuous between 19 and 21
# Not continuous between 23 and 26
# Not continuous between 26 and 28
# Not continuous between 28 and 31
# Not continuous between 31 and 35
# Not continuous between 35 and 38
# Not continuous between 38 and 40
# Not continuous between 45 and 47
# Not continuous between 47 and 49
# Not continuous between 49 and 51
# Not continuous between 53 and 55
# Not continuous between 60 and 62
# Not continuous between 63 and 65
# Not continuous between 65 and 68
# Not continuous between 68 and 70
# Not continuous between 71 and 73
# Not continuous between 75 and 77
# Not continuous between 81 and 83
# Not continuous between 83 and 86
# Not continuous between 86 and 88
# Not continuous between 89 and 92
# Not continuous between 92 and 95
# Not continuous between 95 and 98
# Not continuous between 104 and 106
# Not continuous between 107 and 109
# Not continuous between 113 and 116
# Not continuous between 124 and 126
# Not continuous between 126 and 128
# Not continuous between 128 and 130
# Not continuous between 130 and 133
# Not continuous between 141 and 145
# Not continuous between 150 and 153
# Not continuous between 167 and 170
# Not continuous between 182 and 185
# Not continuous between 186 and 188
# Not continuous between 188 and 190
# Not continuous between 190 and 192
# Not continuous between 195 and 198
# Not continuous between 200 and 202
# Not continuous between 202 and 204
# Not continuous between 204 and 206
# Not continuous between 209 and 213
# Not continuous between 217 and 219
# Not continuous between 223 and 225
# Not continuous between 226 and 228
# Not continuous between 230 and 232
# Not continuous between 240 and 243
# Not continuous between 244 and 246
# Not continuous between 246 and 248
# Not continuous between 248 and 250
# Not continuous between 252 and 255
# Not continuous between 255 and 257
# Not continuous between 263 and 265
# Not continuous between 266 and 271
# Not continuous between 273 and 275
# Not continuous between 277 and 281
# Not continuous between 281 and 283
# Not continuous between 283 and 287
# Not continuous between 290 and 292
# Not continuous between 292 and 294
# Not continuous between 296 and 298
# Not continuous between 299 and 301
# Not continuous between 306 and 309
# Not continuous between 314 and 316
# Not continuous between 316 and 318
# Not continuous between 318 and 320
# Not continuous between 326 and 329
# Not continuous between 332 and 334
# Not continuous between 335 and 338
# Not continuous between 339 and 341
# Not continuous between 342 and 344
# Not continuous between 349 and 351
# Not continuous between 351 and 355
# Not continuous between 356 and 361
# Not continuous between 361 and 363
# Not continuous between 363 and 366
# Not continuous between 367 and 372
# Not continuous between 373 and 375
# Not continuous between 376 and 378
# Not continuous between 378 and 380
# Not continuous between 383 and 385
# Not continuous between 386 and 388
# Not continuous between 391 and 393
# Not continuous between 393 and 397
# Not continuous between 398 and 403
# Not continuous between 403 and 406
# Not continuous between 406 and 408
# Not continuous between 414 and 416
# Not continuous between 416 and 419
# Not continuous between 421 and 423
# Not continuous between 431 and 433
# Not continuous between 435 and 437
# Not continuous between 440 and 442
# Not continuous between 447 and 451
# Not continuous between 452 and 454
# Not continuous between 455 and 457
# Not continuous between 458 and 460
# Not continuous between 465 and 467
# Not continuous between 467 and 470
# Not continuous between 470 and 472
# Not continuous between 476 and 478
# Not continuous between 480 and 484
# Not continuous between 485 and 488
# Not continuous between 489 and 491
# Not continuous between 491 and 493
# Not continuous between 494 and 497
# Not continuous between 502 and 507
# Not continuous between 510 and 512
# Not continuous between 515 and 517
# Not continuous between 518 and 521
# Not continuous between 521 and 524
# Not continuous between 526 and 529
# Not continuous between 533 and 535
# Not continuous between 538 and 540
# Not continuous between 540 and 543
# Not continuous between 545 and 549
# Not continuous between 549 and 551
# Not continuous between 551 and 554
# Not continuous between 554 and 556
# Not continuous between 556 and 558
# Not continuous between 561 and 563
# Not continuous between 570 and 572
# Not continuous between 574 and 576
# Not continuous between 576 and 579
# Not continuous between 580 and 582
# Not continuous between 588 and 590
# Not continuous between 594 and 596
# Not continuous between 596 and 598
# Total not continuous: 132
# <<<<<<<<<<<<<<<<<annotation>>>>>>>>>>>>>>>>
# [0, 1, 2, 3, 4, 5, 6, 8, 11, 13, 14, 15, 16, 18, 19, 21, 22, 23, 26, 28, 31, 35, 38, 40, 41, 42, 43, 44, 45, 47, 49, 51, 52, 53, 55, 56, 57, 58, 59, 60, 62, 63, 65, 68, 70, 71, 73, 74, 75, 77, 78, 79, 80, 81, 83, 86, 88, 89, 92, 95, 98, 99, 100, 101, 102, 103, 104, 106, 107, 109, 110, 111, 112, 113, 116, 117, 118, 119, 120, 121, 122, 123, 124, 126, 128, 130, 133, 134, 135, 136, 137, 138, 139, 140, 141, 145, 146, 147, 148, 149, 150, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 185, 186, 188, 190, 192, 193, 194, 195, 198, 199, 200, 202, 204, 206, 207, 208, 209, 213, 214, 215, 216, 217, 219, 220, 221, 222, 223, 225, 226, 228, 229, 230, 232, 233, 234, 235, 236, 237, 238, 239, 240, 243, 244, 246, 248, 250, 251, 252, 255, 257, 258, 259, 260, 261, 262, 263, 265, 266, 271, 272, 273, 275, 276, 277, 281, 283, 287, 288, 289, 290, 292, 294, 295, 296, 298, 299, 301, 302, 303, 304, 305, 306, 309, 310, 311, 312, 313, 314, 316, 318, 320, 321, 322, 323, 324, 325, 326, 329, 330, 331, 332, 334, 335, 338, 339, 341, 342, 344, 345, 346, 347, 348, 349, 351, 355, 356, 361, 363, 366, 367, 372, 373, 375, 376, 378, 380, 381, 382, 383, 385, 386, 388, 389, 390, 391, 393, 397, 398, 403, 406, 408, 409, 410, 411, 412, 413, 414, 416, 419, 420, 421, 423, 424, 425, 426, 427, 428, 429, 430, 431, 433, 434, 435, 437, 438, 439, 440, 442, 443, 444, 445, 446, 447, 451, 452, 454, 455, 457, 458, 460, 461, 462, 463, 464, 465, 467, 470, 472, 473, 474, 475, 476, 478, 479, 480, 484, 485, 488, 489, 491, 493, 494, 497, 498, 499, 500, 501, 502, 507, 508, 509, 510, 512, 513, 514, 515, 517, 518, 521, 524, 525, 526, 529, 530, 531, 532, 533, 535, 536, 537, 538, 540, 543, 544, 545, 549, 551, 554, 556, 558, 559, 560, 561, 563, 564, 565, 566, 567, 568, 569, 570, 572, 573, 574, 576, 579, 580, 582, 583, 584, 585, 586, 587, 588, 590, 591, 592, 593, 594, 596, 598]
# Not continuous between 6 and 8
# Not continuous between 8 and 11
# Not continuous between 11 and 13
# Not continuous between 16 and 18
# Not continuous between 19 and 21
# Not continuous between 23 and 26
# Not continuous between 26 and 28
# Not continuous between 28 and 31
# Not continuous between 31 and 35
# Not continuous between 35 and 38
# Not continuous between 38 and 40
# Not continuous between 45 and 47
# Not continuous between 47 and 49
# Not continuous between 49 and 51
# Not continuous between 53 and 55
# Not continuous between 60 and 62
# Not continuous between 63 and 65
# Not continuous between 65 and 68
# Not continuous between 68 and 70
# Not continuous between 71 and 73
# Not continuous between 75 and 77
# Not continuous between 81 and 83
# Not continuous between 83 and 86
# Not continuous between 86 and 88
# Not continuous between 89 and 92
# Not continuous between 92 and 95
# Not continuous between 95 and 98
# Not continuous between 104 and 106
# Not continuous between 107 and 109
# Not continuous between 113 and 116
# Not continuous between 124 and 126
# Not continuous between 126 and 128
# Not continuous between 128 and 130
# Not continuous between 130 and 133
# Not continuous between 141 and 145
# Not continuous between 150 and 153
# Not continuous between 167 and 170
# Not continuous between 182 and 185
# Not continuous between 186 and 188
# Not continuous between 188 and 190
# Not continuous between 190 and 192
# Not continuous between 195 and 198
# Not continuous between 200 and 202
# Not continuous between 202 and 204
# Not continuous between 204 and 206
# Not continuous between 209 and 213
# Not continuous between 217 and 219
# Not continuous between 223 and 225
# Not continuous between 226 and 228
# Not continuous between 230 and 232
# Not continuous between 240 and 243
# Not continuous between 244 and 246
# Not continuous between 246 and 248
# Not continuous between 248 and 250
# Not continuous between 252 and 255
# Not continuous between 255 and 257
# Not continuous between 263 and 265
# Not continuous between 266 and 271
# Not continuous between 273 and 275
# Not continuous between 277 and 281
# Not continuous between 281 and 283
# Not continuous between 283 and 287
# Not continuous between 290 and 292
# Not continuous between 292 and 294
# Not continuous between 296 and 298
# Not continuous between 299 and 301
# Not continuous between 306 and 309
# Not continuous between 314 and 316
# Not continuous between 316 and 318
# Not continuous between 318 and 320
# Not continuous between 326 and 329
# Not continuous between 332 and 334
# Not continuous between 335 and 338
# Not continuous between 339 and 341
# Not continuous between 342 and 344
# Not continuous between 349 and 351
# Not continuous between 351 and 355
# Not continuous between 356 and 361
# Not continuous between 361 and 363
# Not continuous between 363 and 366
# Not continuous between 367 and 372
# Not continuous between 373 and 375
# Not continuous between 376 and 378
# Not continuous between 378 and 380
# Not continuous between 383 and 385
# Not continuous between 386 and 388
# Not continuous between 391 and 393
# Not continuous between 393 and 397
# Not continuous between 398 and 403
# Not continuous between 403 and 406
# Not continuous between 406 and 408
# Not continuous between 414 and 416
# Not continuous between 416 and 419
# Not continuous between 421 and 423
# Not continuous between 431 and 433
# Not continuous between 435 and 437
# Not continuous between 440 and 442
# Not continuous between 447 and 451
# Not continuous between 452 and 454
# Not continuous between 455 and 457
# Not continuous between 458 and 460
# Not continuous between 465 and 467
# Not continuous between 467 and 470
# Not continuous between 470 and 472
# Not continuous between 476 and 478
# Not continuous between 480 and 484
# Not continuous between 485 and 488
# Not continuous between 489 and 491
# Not continuous between 491 and 493
# Not continuous between 494 and 497
# Not continuous between 502 and 507
# Not continuous between 510 and 512
# Not continuous between 515 and 517
# Not continuous between 518 and 521
# Not continuous between 521 and 524
# Not continuous between 526 and 529
# Not continuous between 533 and 535
# Not continuous between 538 and 540
# Not continuous between 540 and 543
# Not continuous between 545 and 549
# Not continuous between 549 and 551
# Not continuous between 551 and 554
# Not continuous between 554 and 556
# Not continuous between 556 and 558
# Not continuous between 561 and 563
# Not continuous between 570 and 572
# Not continuous between 574 and 576
# Not continuous between 576 and 579
# Not continuous between 580 and 582
# Not continuous between 588 and 590
# Not continuous between 594 and 596
# Not continuous between 596 and 598
# Total not continuous: 132
# image cannot find a match at anno: []
# anno cannot find a match at image: []
