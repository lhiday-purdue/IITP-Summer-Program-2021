# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# working directory
# !find /content/drive/ -name UAV -type d > path.txt
file = open('path.txt', 'r')
Path = file.read()
Path = Path.strip()

# %%
img_path = Path + '/Camera_infrared/imagesCaptured'
print(img_path)
# Out:
# /content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured

# %%
import glob
from PIL import Image

img_list = glob.glob(img_path + '/*')
images = [file for file in img_list if file.endswith(".jpg") or file.endswith(".JPG")]

print ("images: {}".format(images))
# Out:
# images: ['/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_6.jpg', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_9.jpg', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_30.jpg', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_32.jpg', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_41.jpg', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_43.jpg', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_36.jpg', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_34.jpg', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_35.jpg', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Camera_infrared/imagesCaptured/image_8.jpg', '/content/drive/Othercomputers/MyLaptop/YO
# ...

# %%
num = 1
for image_file in images:
  image = Image.open(image_file)
  resize_image = image.resize((320, 320))
  str_num = (4 - len(str(num)))*'0'+str(num)
  resize_image.save(Path+"/Camera_infrared/resized_InfraredImg/"+str_num+'.JPG')
  num += 1

# %%
# the annotation file needs to be change (previous one contains local info)
import xml.etree.ElementTree as ET

def changeLabel(xmlPath, newXmlPath):
  tree = ET.parse(xmlPath)  
  root = tree.getroot()

  # change path
  path = root.find('path')
  path.text = xmlPath

  tree.write(newXmlPath)

# %% [markdown]
# create anno file which maps with resized img

# %%
! pip install labelImg

# %%
# !labelImg
# Out:
# qt.qpa.xcb: could not connect to display
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl, xcb.

# %%
xml_path =  Path + '/Model/dataset/resize_img/'
print(xml_path)
# Out:
# /content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/

# %%
xml_list = glob.glob(xml_path + '*')
xml_fileList = [file for file in xml_list if file.endswith(".xml")]

print ("file: {}".format(xml_fileList))

i = 0
for xml in xml_fileList:
  changeLabel(xml_fileList[i], xml_fileList[i])
  i += 1
# Out:
# file: ['/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0091.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0057.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0203.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0066.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0062.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0139.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0165.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0060.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0079.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0232.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/dataset/resize_img/0109.xml', '/content/drive/Othercomputers/MyLaptop/YOLO/UAV/Model/d
# ...
