# %%
# !git clone https://github.com/eriklindernoren/PyTorch-YOLOv3
# %cd PyTorch-YOLOv3/
# !pip3 install poetry --user
# !poetry install
# Out:
# Cloning into 'PyTorch-YOLOv3'...
# remote: Enumerating objects: 1603, done.
# remote: Total 1603 (delta 0), reused 0 (delta 0), pack-reused 1603
# Receiving objects: 100% (1603/1603), 16.42 MiB | 22.09 MiB/s, done.
# Resolving deltas: 100% (961/961), done.
# /content/PyTorch-YOLOv3
# ...
#      |████████████████████████████████| 174kB 8.8MB/s
# ...
#      |████████████████████████████████| 92kB 7.3MB/s
# ...
#      |████████████████████████████████| 7.2MB 13.8MB/s
# ...
#      |████████████████████████████████| 61kB 7.8MB/s
# ...
#      |████████████████████████████████| 430kB 30.4MB/s
# ...
#      |████████████████████████████████| 51kB 7.4MB/s
# ...
#      |████████████████████████████████| 348kB 30.1MB/s
# ...
#      |████████████████████████████████| 3.2MB 43.8MB/s
# ...
#   WARNING: The script keyring is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
ls
# Out:
# assets/  data/    poetry.lock     pytorchyolo/  weights/
# config/  LICENSE  pyproject.toml  README.md

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O ./weights/download_weights.sh
# Out:
# --2021-07-05 18:54:30--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘./weights/download_weights.sh’
#
# ./weights/download_ 100%[===================>] 236.52M  71.7MB/s    in 3.5s
#
# 2021-07-05 18:54:34 (67.2 MB/s) - ‘./weights/download_weights.sh’ saved [248007048/248007048]
